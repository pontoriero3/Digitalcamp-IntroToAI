# %% [markdown]
# # Getting Started with Python

# %% [markdown]
# ## Hello world

# %% [markdown]
# The simplest and most ubiqitous function in Python is the print function. To print a statement simply type:

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ## Commenting

# %% [markdown]
# It is always important to comment code such that others can read and use it. In Python there are two approaches to code commenting: 1) using ```#```

# %%
# this is a code comment

# %% [markdown]
# ## Variables and Types

# %% [markdown]
# ### Numbers

# %% [markdown]
# Python supports three types of numbers:
#     - integers
#     - floats
#     - complex  numbers
#
# An example of assigning a variable an integer value is:

# %%
myint = 9
print('example integer is ', myint)
# Out:
# example integer is  9

# %% [markdown]
# Examples of float declarations are:

# %%
myfloat1 = 9.3
myfloat2 = float(9)
print('example integer is ', myfloat1)
print('casting an integer as a float results in', myfloat2)
# Out:
# example integer is  9.3
# casting an integer as a float results in 9.0

# %%
# TO DO

# create a variable a and assign it a value of 50
# print the value of a

# %% [markdown]
# ### Strings

# %% [markdown]
# Strings are defined either with a single quote or a double quotes e.g.

# %%
string1="hello world" # If apostrophe inside is needed, use "" --> "Steve's dog"
string2='hello world'
print(string1)
print(string2)
# Out:
# hello world
# hello world
# testing if string1 and string2 are equal: True

# %%
# TO DO

# create a variable myString and assign it any sentence/word you'd like
# print the myString

# %% [markdown]
# ### Operators

# %% [markdown]
# The basic math operators are:
# - addition (```+```)
# - subtraction (```-```)
# - multiplication (```*```)
# - division (```/``` or ```//```)

# %%
print('addition:', 2+3)
print('subtraction:', 2-3)
print('multiplication:', 2*3)
print('division:', 2/3)

a=9
b=5
print('The remainder following division of {} by {} is {}'.format(a, b, a%b))

a=2
b=4
print('{} to the power {} is {}'.format(a, b, a**b))

# multiply strings
print('hello'*10)
# Out:
# addition: 5
# subtraction: -1
# multiplication: 6
# division: 0.6666666666666666
# The remainder following division of 9 by 5 is 4
# 2 to the power 4 is 16
# hellohellohellohellohellohellohellohellohellohello
# hello10
# hello10
# hello10

# %%
# TO DO

# create two new variables a and b and assign them integer numbers.
# Then, print their sum and division

# %% [markdown]
# ### Conditions

# %% [markdown]
# Conditions containing boolean operators ``` == > < ``` are formatted as:

# %%
a=10          # =  assignment,  a is equal to 10.
print(a==10)  # == comparison,  is a equal to 10?
print(a<12)   # <  comparison,  is a lower than 12?
print(a>20)   # >  comparison,  is a greater than 20?
# Out:
# True
# True
# False

# %% [markdown]
# Two conditional statements can be considered concurrent with ```and,or, and is``` statements

# %%
a=10
b=12
print(a is b)
print(a< 15 and b > 10)
print (a < 15 or b < 10)
# Out:
# False
# True
# True

# %% [markdown]
# ### Lists

# %% [markdown]
# A list is an ordered collection of objects. List elements don't have to be of the same type but can be an arbitrary mixture of numbers, strings, or other types of objects. Lists can contain other lists as sub-lists. Examples of lists:

# %%
emptylist=[] # An empty list

integerlist=[1,2,3,4,5,6] #A list of integers

stringlist=['string1', 'string2', 'string3'] #A list of strings

mixedlist=[10, "some string", 4.2, 2, 'some other string'] #A list of mixed data types

# a nested list  - note sublists are not same lengths
nestedlist=[['dog','cat','pig'], [1,2,3 ,4], [10, "some string", 4.2, 2, 'some other string'] ]

# %%
# TO DO

# create a list of integers and print it

# %% [markdown]
# ### Tuples

# %% [markdown]
# Tuples are immutable lists. They are defined analogously to lists, except that the set of elements is enclosed in parentheses instead of square brackets:

# %%
mytuple=(10,"Dog's", 4.2)
print('My tuple index 2:', mytuple[1])
# Out:
# My tuple index 2: Dog's

# %% [markdown]
# ### Dictionaries

# %% [markdown]
# In many ways dictionaries are similar to lists: they can contain any type of object, be easily changed, and appended at run time. However unlike lists Dictionaries are unordered, indexed instead using keys

# %%
mydict={}
mydict['Name']='Dave'
mydict['Age']=23
mydict['job']='Lecturer'
mydict['height']=190

mydict[5]='val1'
mydict[3.2413]='val2'
mydict[(1,2,3)]='val3'

# try to access a key that is not in the dictionary. What happens?
mydict['heights'] # instead of height
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [18], in <cell line: 12>()
#       9 mydict[(1,2,3)]='val3'
#      11 # try to access a key that is not in the dictionary. What happens?
# ---> 12 mydict['heights']
#
# KeyError: 'heights'

# %% [markdown]
# ### For Loop

# %%
# list we want to inspect
listOfUnits = [1,2,3,4,5]

for unit in listOfUnits:
    # a for loop over the list of units
    print('Output of third code block; The new number is', unit)

# TO DO: 
# Copy the code above and instead of printing the unit, print the square of unit

# %% [markdown]
# ## BONUS - Make Your First Python Game: Rock, Paper, Scissors!

# %% [markdown]
# Rock, paper, scissors is a hand game for two or more players.
# Participants say “rock, paper, scissors” and then simultaneously form their hands into the shape of a rock, a piece of paper, or a pair of scissors.
#
# The rules are straightforward:
#  - Rock smashes scissors.
#  - Paper covers rock.
#  - Scissors cut paper.
#
# Can you think about how these rules might translate to Python code?

# %%
import random

user_action = input("Enter a choice (rock, paper, scissors): ") # This is the action you type.
possible_actions = ["rock", "paper", "scissors"]                # This is the list of possible actions that the computer will randomly choose from.
computer_action = random.choice(possible_actions)               # This is the randomly chosen action by the computer

# Printing the actions chosen by the user and the computer
print(f"\nYou chose {user_action}, computer chose {computer_action}.\n")

# first case: both players choose the same action
if user_action == computer_action:
    print(f"Both players selected {user_action}. It's a tie!")
# second case: the user chooses rock
elif user_action == "rock":
    # second case: the computer chooses scissors and loses
    if computer_action == "scissors":
        print("Rock smashes scissors! You win!")
    # second case: the computer chooses rock and wins
    else:
        print("Paper covers rock! You lose.")
# third case: the user chooses paper
elif user_action == "paper":
    # TO DO
    # Can you code the conditions in this case?
    # if computer_action == ......
    # 
    # else:
    # 
# fourth case: the user chooses scissors
elif user_action == "scissors":
    # TO DO
    # Can you code the conditions in this case?
    # if computer_action == ......
    # 
    # else:
    #
# Out:
# You chose rock, computer chose rock.
#
# Both players selected rock. It's a tie!
